# %% [markdown]
# # 1. import

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/juyoungkim/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in /Users/juyoungkim/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import pandas as pd
import re
import numpy as np

# %%
def read_csv(file_path):
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        matrix = []
        matrix_new = []
        for i, row in enumerate(reader):
            if i < 4:
                pass
            else :
                matrix = []                
                for i, data in enumerate(row):
                    if i > 7 and i < 15:
                        matrix.append(data)
            
            matrix_new.append(matrix)
        # print(matrix_new)
        print("-------------------")
        matrix3 = []
        matrix4 = []
        for i in matrix_new:
            for x in i:
               if x != '':
                   matrix3.append(x)
                #    print(matrix3)
            
            matrix4.append(matrix3)
        # print(matrix4)
        # for i, row in enumerate(reader):
    return matrix4

#CSV 파일 경로 설정
csv_file_path = "/Users/juyoungkim/Development/aie/Hackathon/test_set.csv"

#CSV 파일 읽기 및 데이터 표시
matrix4 = read_csv(csv_file_path)
matrix_final = matrix4[0]
print(matrix_final)
df = pd.DataFrame(matrix_final)
excel_file_path = '/Users/juyoungkim/Development/aie/Hackathon/output.xlsx'
df.to_excel(excel_file_path, index=False, header=False)
# Out:
# -------------------
# ['AIC2100', '01', '인공지능프로그래밍', '이병주', '3', 'A+', 'CCO2103', '02', '자료구조', '황성재', '3', 'A+', 'GAI2006', '01', '이산구조론', '김택헌', '3', 'A+', 'GAI3004', '01', '자연어정보분석', '유정민', '3', 'A+', 'GAI3005', '01', '고급데이터분석', '유정민', '3', 'A+', 'GAI2001', '01', '응용자료구조', '김택헌', '3', 'A+', 'GAI2003', '01', '데이터베이스개론', '박창희', '3', 'A+', 'GAI2004', '01', '데이터분석개론', '유정민', '3', 'W', 'GAI3007', '01', '정보SW공학', '박지호', '3', 'A+', 'GCM3030', '01', '미디어산업의발전', '강루가', '1', 'P', 'GLC1252', '01', '문학의이해와감상', '이한빛', '3', 'A+', 'UCK1162', '01', 'BOOK CLUB(1)', '전진희', '1', 'P', 'UCL1106', '04', '펜싱', '안효준', '1', 'P', 'UCR1010', '02', 'RA리더십개발론', '한봉환', '2', 'A+', 'UCR1011', '09', 'RA리더십개발실습(1)', '손영종', '1', 'P', 'YCA1008', '02', '채플(D)', '정미현', '0.5', 'P', 'CSI2102', '01', '객체지향프로그래밍', '이인권', '3', 'A+', 'GAI2008', '01', '정보프로그래밍2', '유정민', '3', 'A+', 'GAI3002', '01', '인공지능기초수학', '어영정', '3', 'A+', 'GLC1224', '01', '동아시아세계,한국사와한국 문화', '장병진', '3', 'A+', 'UCC1106', '02', '우주의이해', '이영욱', '3', 'A+', 'YCA1007', '01', '채플(C)', '이대성, 정종훈,', '0.5', 'P', 'YCS1005', '01', 'ICT산업연계프로젝트', '나정은', '3', 'A+', 'ECO1001', '05', '경제학입문', '이재황', '3', 'A+', 'GLC1203', '01', '숫자와생활', '이은지', '3', 'A+', 'GLC1208', '01', 'GLC수학', '한혜림', '3', 'A+', 'GLC1266', '01', '프로그래밍을통한논리적사고', '최상민', '3', 'A+', 'UCR1014', '09', 'RC자기주도활동(2)', '손영종', '0.5', 'P', 'YCA1006', '02', '채플(B)', '곽호철', '0.5', 'P', 'YCF1501', '04', '프랑스어(1)', '송지연', '3', 'B+', 'YCS1102', '01', '컴퓨터시스템과피지컬컴퓨팅', '김신덕', '3', 'A0', 'GAI1001', '01', '정보컴퓨팅기술개론', '이종빈', '3', 'A+', 'GAI1002', '01', '정보프로그래밍1', '이종빈', '3', 'A+', 'GLC1205', '01', '한국의문화적사건', '김유미', '3', 'A+', 'GLC1250', '01', 'GLC선형대수', '한혜림', '3', 'A+', 'UCI1175', '01', '연세정신과인권', '김왕배', '1', 'P', 'UCK1164', '03', 'BOOK CLUB(3)', '베켓제 레미', '1', 'P', 'UCR1007', '80', 'YONSEI RC 101-GLD', '유성은', '1', 'P', 'UCR1013', '09', 'RC자기주도활동(1)', '손영종', '0.5', 'P', 'YCA1005', '02', '채플(A)', '정용한', '0.5', 'P', 'YCA1101', '11', '기독교와세계문화', '홍성표', '3', 'A+', 'GLC1006', '01', 'GLC영어1', '0', 'GLC1007', '01', 'GLC영어2', '0']

# %%
# def read_csv(file_path):
#     with open(file_path, 'r') as file:
#         reader = csv.reader(file)
#         for i, row in enumerate(reader):
#             # print(ro÷w)
#             if re.match(r'^20', row[0]):
#                 print(row)
#             # print(f"{i} : {row}",i, row)
            
#         print("reader[0] : ",reader)
# #CSV 파일 경로 설정
# csv_file_path = "/Users/juyoungkim/Development/aie/Hackathon/test_set.csv"

# #CSV 파일 읽기 및 데이터 표시
# read_csv(csv_file_path)

# %%
def read_csv_pandas(file_path):
    df = pd.read_csv(file_path)
    print(df)

read_csv_pandas(csv_file_path)
# Out:
#                    기본 정보 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0                     학번        NaN  2021106129        NaN        NaN  \
# 1                   재학구분        NaN    일반휴학(가사)        NaN        NaN
# 2                     학기         신청         NaN         취득         평균
# 3           2023학년도 1학 기         15         NaN         15       4.30
# 4                    NaN        NaN         NaN        NaN        NaN
# 5                    NaN        NaN         NaN        NaN        NaN
# 6                    NaN        NaN         NaN        NaN        NaN
# 7                    NaN        NaN         NaN        NaN        NaN
# 8           2022학년도 2학 기       18.5         NaN       18.5       4.30
# 9                    NaN        NaN         NaN        NaN        NaN
# 10                   NaN        NaN         NaN        NaN        NaN
# 11                   NaN        NaN         NaN        NaN        NaN
# 12                   NaN        NaN         NaN        NaN        NaN
# 13                   NaN        NaN         NaN        NaN        NaN
# 14                   NaN        NaN         NaN        NaN        NaN
# 15                   NaN        NaN         NaN        NaN        NaN
# 16                   NaN        NaN         NaN        NaN        NaN
# 17                   NaN        NaN         NaN        NaN        NaN
# 18                   NaN        NaN         NaN        NaN        NaN
# 19          2022학년도 1학 기       18.5         NaN       18.5       4.30
# 20                   NaN        NaN         NaN        NaN        NaN
# 21                   NaN        NaN         NaN        NaN        NaN
# 22                   NaN        NaN         NaN        NaN        NaN
# 23                   NaN        NaN         NaN        NaN        NaN
# 24                   NaN        NaN         NaN        NaN        NaN
# 25                   NaN        NaN         NaN        NaN        NaN
# 26          2021학년도 2학 기         19         NaN         19       4.08
# 27                   NaN        NaN         NaN        NaN        NaN
# 28                   NaN        NaN         NaN        NaN        NaN
# 29                   NaN        NaN         NaN        NaN        NaN
# 30                   NaN        NaN         NaN        NaN        NaN
# 31                   NaN        NaN         NaN        NaN        NaN
# 32          2021학년도 2학 기         19         NaN         19       4.08
# 33                   NaN        NaN         NaN        NaN        NaN
# 34          2021학년도 1학 기         19         NaN         19       4.30
# 35                   NaN        NaN         NaN        NaN        NaN
# 36                   NaN        NaN         NaN        NaN        NaN
# 37                   NaN        NaN         NaN        NaN        NaN
# 38                   NaN        NaN         NaN        NaN        NaN
# 39                   NaN        NaN         NaN        NaN        NaN
# 40                   NaN        NaN         NaN        NaN        NaN
# 41                   NaN        NaN         NaN        NaN        NaN
# 42                   NaN        NaN         NaN        NaN        NaN
# 43                   NaN        NaN         NaN        NaN        NaN
# 44          2021학년도 0학 기          0         NaN          0       0.00
# 45                   NaN        NaN         NaN        NaN        NaN
# 46                     계         90         NaN         90       4.25
# 47  * 성적참조구분\nZ3 : 교과목인정        NaN         NaN        NaN        NaN
#
#    Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8 Unnamed: 9  ...
# 0         NaN        NaN                 NaN         성명        NaN  ...  \
# 1         NaN        NaN                 NaN         소속        NaN  ...
# 2         백분위    4.5\n환산               과목 종별       학정번호         분반  ...
# 3    100.\n00       4.50                  전선    AIC2100         01  ...
# 4         NaN        NaN                  전필    CCO2103         02  ...
# 5         NaN        NaN                  전기    GAI2006         01  ...
# 6         NaN        NaN                  전선    GAI3004         01  ...
# 7         NaN        NaN                  전선    GAI3005         01  ...
# 8    100.\n00       4.50                  전기    GAI2001         01  ...
# 9         NaN        NaN                  전필    GAI2003         01  ...
# 10        NaN        NaN                  전선    GAI2004         01  ...
# 11        NaN        NaN                  전필    GAI3007         01  ...
# 12        NaN        NaN                  전선    GCM3030         01  ...
# 13        NaN        NaN                  대교    GLC1252         01  ...
# 14        NaN        NaN                  자율    UCK1162         01  ...
# 15        NaN        NaN                  대교    UCL1106         04  ...
# 16        NaN        NaN                  선교    UCR1010         02  ...
# 17        NaN        NaN                  선교    UCR1011         09  ...
# 18        NaN        NaN                  공기    YCA1008         02  ...
# 19   100.\n00       4.50                  전필    CSI2102         01  ...
# 20        NaN        NaN                  전기    GAI2008         01  ...
# 21        NaN        NaN                  전기    GAI3002         01  ...
# 22        NaN        NaN                  대교    GLC1224         01  ...
# 23        NaN        NaN                  대교    UCC1106         02  ...
# 24        NaN        NaN                  교기    YCA1007         01  ...
# 25        NaN        NaN                  대교    YCS1005         01  ...
# 26    98.3\n0       4.22                  대교    ECO1001         05  ...
# 27        NaN        NaN                  대교    GLC1203         01  ...
# 28        NaN        NaN                  대교    GLC1208         01  ...
# 29        NaN        NaN                  대교    GLC1266         01  ...
# 30        NaN        NaN                  선교    UCR1014         09  ...
# 31        NaN        NaN                  교기    YCA1006         02  ...
# 32    98.3\n0       4.22                  대교    YCF1501         04  ...
# 33        NaN        NaN                  대교    YCS1102         01  ...
# 34   100.\n00       4.50                  전기    GAI1001         01  ...
# 35        NaN        NaN                  전기    GAI1002         01  ...
# 36        NaN        NaN                  대교    GLC1205         01  ...
# 37        NaN        NaN                  대교    GLC1250         01  ...
# 38        NaN        NaN                  자율    UCI1175         01  ...
# 39        NaN        NaN                  자율    UCK1164         03  ...
# 40        NaN        NaN                  선교    UCR1007         80  ...
# 41        NaN        NaN                  RC    UCR1013         09  ...
# 42        NaN        NaN                  교기    YCA1005         02  ...
# 43        NaN        NaN                  교기    YCA1101         11  ...
# 44       0.00       0.00                  교기    GLC1006         01  ...
# 45        NaN        NaN                  교기    GLC1007         01  ...
# 46      99.60       4.41  환산점수 -> 99.6 / 100        NaN        NaN  ...
# 47        NaN        NaN                 NaN        NaN        NaN  ...
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0          NaN         NaN         NaN          학년         NaN         NaN  \
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2         담당교수          학점          평가         NaN         백분위          비고
# 3          이병주           3          A+         NaN         100         NaN
# 4          황성재           3          A+         NaN         100         NaN
# 5          김택헌           3          A+         NaN         100         NaN
# 6          유정민           3          A+         NaN         100         NaN
# 7          유정민           3          A+         NaN         100         NaN
# 8          김택헌           3          A+         NaN         100         NaN
# 9          박창희           3          A+         NaN         100         NaN
# 10         유정민           3           W         NaN           0         NaN
# 11         박지호           3          A+         NaN         100         NaN
# 12         강루가           1           P         NaN           0         NaN
# 13         이한빛           3          A+         NaN         100         NaN
# 14         전진희           1           P         NaN           0         NaN
# 15         안효준           1           P         NaN           0         NaN
# 16         한봉환           2          A+         NaN         100         NaN
# 17         손영종           1           P         NaN           0         NaN
# 18         정미현         0.5           P         NaN           0         NaN
# 19         이인권           3          A+         NaN         100         NaN
# 20         유정민           3          A+         NaN         100         NaN
# 21         어영정           3          A+         NaN         100         NaN
# 22         장병진           3          A+         NaN         100         NaN
# 23         이영욱           3          A+         NaN         100         NaN
# 24   이대성, 정종훈,         0.5           P         NaN           0         NaN
# 25         나정은           3          A+         NaN         100         NaN
# 26         이재황           3          A+         NaN         100         NaN
# 27         이은지           3          A+         NaN         100         NaN
# 28         한혜림           3          A+         NaN         100         NaN
# 29         최상민           3          A+         NaN         100         NaN
# 30         손영종         0.5           P         NaN           0         NaN
# 31         곽호철         0.5           P         NaN           0         NaN
# 32         송지연           3          B+         NaN          89         NaN
# 33         김신덕           3          A0         NaN          96         NaN
# 34         이종빈           3          A+         NaN         100         NaN
# 35         이종빈           3          A+         NaN         100         NaN
# 36         김유미           3          A+         NaN         100         NaN
# 37         한혜림           3          A+         NaN         100         NaN
# 38         김왕배           1           P         NaN           0         NaN
# 39      베켓제 레미           1           P         NaN           0         NaN
# 40         유성은           1           P         NaN           0         NaN
# 41         손영종         0.5           P         NaN           0         NaN
# 42         정용한         0.5           P         NaN           0         NaN
# 43         홍성표           3          A+         NaN         100         NaN
# 44         NaN           0         NaN         NaN         NaN         NaN
# 45         NaN           0         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN         NaN
# 47         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 18 Unnamed: 19  Unnamed: 20 Unnamed: 21
# 0          3.0         NaN          NaN         NaN
# 1          NaN         NaN          NaN         NaN
# 2          NaN         NaN      4.5\n환산         NaN
# 3          NaN         NaN         4.50         NaN
# 4          NaN         NaN         4.50         NaN
# 5          NaN         NaN         4.50         NaN
# 6          NaN         NaN         4.50         NaN
# 7          NaN         NaN         4.50         NaN
# 8          NaN         NaN         4.50         NaN
# 9          NaN         NaN         4.50         NaN
# 10         NaN         NaN         0.00         NaN
# 11         NaN         NaN         4.50         NaN
# 12         NaN         NaN         0.00         NaN
# 13         NaN         NaN         4.50         NaN
# 14         NaN         NaN         0.00         NaN
# 15         NaN         NaN         0.00         NaN
# 16         NaN         NaN         4.50         NaN
# 17         NaN         NaN         0.00         NaN
# 18         NaN         NaN         0.00         NaN
# 19         NaN         NaN         4.50         NaN
# 20         NaN         NaN         4.50         NaN
# 21         NaN         NaN         4.50         NaN
# 22         NaN         NaN         4.50         NaN
# 23         NaN         NaN         4.50         NaN
# 24         NaN         NaN         0.00         NaN
# 25         NaN         NaN         4.50         NaN
# 26         NaN         NaN         4.50         NaN
# 27         NaN         NaN         4.50         NaN
# 28         NaN         NaN         4.50         NaN
# 29         NaN         NaN         4.50         NaN
# 30         NaN         NaN         0.00         NaN
# 31         NaN         NaN         0.00         NaN
# 32         NaN         NaN         3.54         NaN
# 33         NaN         NaN         4.15         NaN
# 34         NaN         NaN         4.50         NaN
# 35         NaN         NaN         4.50         NaN
# 36         NaN         NaN         4.50         NaN
# 37         NaN         NaN         4.50         NaN
# 38         NaN         NaN         0.00         NaN
# 39         NaN         NaN         0.00         NaN
# 40         NaN         NaN         0.00         NaN
# 41         NaN         NaN         0.00         NaN
# 42         NaN         NaN         0.00         NaN
# 43         NaN         NaN         4.50         NaN
# 44         NaN          Z3          NaN         NaN
# 45         NaN          Z3          NaN         NaN
# 46         NaN         NaN          NaN         NaN
# 47         NaN         NaN          NaN         NaN
#
# [48 rows x 22 columns]
